# %%
import pandas as pd
import numpy as np
import os

# %%
data= pd.read_csv(r"C:\Users\vedan\Downloads\netflix_titles.csv\netflix_titles.csv")

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.columns #to get the columns of the dataset
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.shape #to get the shape of the dataset
# Out:
# (8807, 12)

# %%
data.info()# to get the information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.describe() # to get the description of the dataset
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
duplicates= data.duplicated()
print(duplicates.sum())
# Out:
# 0

# %%
# to get the null values in the dataset
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#to fill the null values with a specific value in the dataset
data['director'].fillna('NaN',inplace=True)
data['country'].fillna('NaN',inplace=True)
data['cast'].fillna('NaN',inplace=True)
data['rating'].fillna('NaN',inplace=True)
data['date_added'].fillna('NaN',inplace=True)
data['duration'].fillna('NaN',inplace=True)
# Out:
# C:\Users\vedan\AppData\Local\Temp\ipykernel_31292\3702815090.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['director'].fillna('NaN',inplace=True)
# C:\Users\vedan\AppData\Local\Temp\ipykernel_31292\3702815090.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
data.isnull().sum() #to check the null values in the dataset after filling the null values
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added       0
# release_year     0
# rating           0
# duration         0
# listed_in        0
# description      0
# year_added      98
# month_added     98
# dtype: int64

# %%
data.isnull().sum() #to check the null values in the dataset after filling the null values in all the columns
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added       0
# release_year     0
# rating           0
# duration         0
# listed_in        0
# description      0
# year_added      98
# month_added     98
# dtype: int64

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
data.drop(['month_added'],axis=1,inplace=True)

# %%
#To check for any duplicates in the dataset
duplicates = data.duplicated()
print(duplicates.sum())
# Out:
# 0

# %%
#
data.drop_duplicates()
# Out:
#      SHOW_ID     TYPE                  TITLE         DIRECTOR  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    CAST        COUNTRY  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
#to drop the duplicates in the specific columns in the dataset
data.drop_duplicates(subset=['title', 'date_added','type','show_id'], inplace=True)

# %%
#Standardizing the column names
data.columns = data.columns.str.upper().str.replace(' ','_')

# %%
country_map={
    "Australia":"AUS",
    "Argentina":"ARG",
    "Austria":"AUT",
    "Bangladesh":"BAN",
    "Belarus":"BLR",
    "Belgium":"BEL",
    "Brazil":"BRA",
    "Bulgaria":"BGR",
    "Canada":"CAN",
    "Chile":"CHL",
    "Columbia":'COL',
    'Guatemala': 'GT',
    'Hungary': 'HU',
    'Iceland': 'IS',
    'India': 'IN',
    'Indonesia': 'ID',
    'Iran': 'IR',
    'Ireland': 'IE',
    'Israel': 'IL',
    "United States":"USA",
    "United Kingdom":"UK",
    "South Korea":"KOR",
    "Czech Republic":"CZE",
    "Cayman Islands":"CAY",
    "South Africa":"SA",
    "New Zealand":"NZ",
    "United Arab Emirates":"UAE",
    "Phillippines":"PH",
    "Luxembourg":"LUX",
    "Hong Kong":"HK",
    "South Africa":"SA",
    "Switzerland":"CHE",
    "Sweden":"SE",
    "Syria":"SY",
    "Taiwan":"TW",
    "Thailand":"TH",
    "Turkey":	"TR",
    "Ukraine"	:"UA",
    "Uruguay": "UY",
    "Venezuela": "VE",
    "Vietnam": "VN",
    "Germany": "GER",
    "Zimbabwe": "ZW"
}

# %%
#to get the short form of the country names in the above dictionary made
data['country'] = data['country'].replace(country_map)

# %%
data.drop(['country_cleaned', 'country_code'], axis=1, inplace=True)

# %%
data.head()
# Out:
#   SHOW_ID     TYPE                  TITLE         DIRECTOR  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 CAST COUNTRY  \
# 0                                                NaN     USA
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...      SA
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
# 3                                                NaN     NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...      IN
#
#            DATE_ADDED  RELEASE_YEAR RATING   DURATION  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
data.columns = data.columns.str.title().str.replace(' ','_')

# %%
data.head()
# Out:
#   Show_Id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast Country  \
# 0                                                NaN     USA
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...      SA
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN
# 3                                                NaN     NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...      IN
#
#            Date_Added  Release_Year Rating   Duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
#To get the data types of the columns of the dataset
print(data.dtypes)
# Out:
# Show_Id         object
# Type            object
# Title           object
# Director        object
# Cast            object
# Country         object
# Date_Added      object
# Release_Year     int64
# Rating          object
# Duration        object
# Listed_In       object
# Description     object
# dtype: object

# %%
data['Date_Added'] = pd.to_datetime(data['Date_Added'], errors='coerce')

# %%
#filling the null or missing values for date_added column:
data['Date_Added'].fillna(pd.Timestamp('2023-01-01'),inplace=True)# to fill the null values with a specific date in the date_added column
# Out:
# C:\Users\vedan\AppData\Local\Temp\ipykernel_27756\2439067996.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Date_Added'].fillna(pd.Timestamp('2023-01-01'),inplace=True)# to fill the null values with a specific date in the date_added column

# %%
data.head()
# Out:
#   Show_Id     Type                  Title         Director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 Cast Country Date_Added  \
# 0                                                NaN     USA 2021-09-25
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...      SA 2021-09-24
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...     NaN 2021-09-24
# 3                                                NaN     NaN 2021-09-24
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...      IN 2021-09-24
#
#    Release_Year Rating   Duration  \
# 0          2020  PG-13     90 min
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
# ...

# %%
#to get the data types of the columns of the dataset after filling the null values in the date_added column:
print(data.dtypes)
# Out:
# Show_Id                 object
# Type                    object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Date_Added      datetime64[ns]
# Release_Year             int64
# Rating                  object
# Duration                object
# Listed_In               object
# Description             object
# dtype: object
